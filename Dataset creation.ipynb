# %%
import pandas as pd
import numpy as np

# Set seed for reproducibility
np.random.seed(42)

# Define the number of rows and columns in the dataset
num_rows = 100000
num_columns = 100

# Create a random dataset with duplicates
data = np.random.randint(1, 10, size=(num_rows, num_columns))
df = pd.DataFrame(data, columns=[f'Column_{i}' for i in range(1, num_columns + 1)])

# Introduce duplicates in the dataset
duplicate_indices = np.random.choice(df.index, size=int(0.1 * num_rows), replace=False)
df.loc[duplicate_indices] = df.iloc[np.random.choice(df.index, size=len(duplicate_indices))].values

# Reset index
df.reset_index(drop=True, inplace=True)

# Display the dataset
df
# Out:
#        Column_1  Column_2  Column_3  Column_4  Column_5  Column_6  Column_7  \
# 0             7         4         8         5         7         3         7
# 1             3         5         3         1         5         7         7
# 2             1         9         9         2         7         3         7
# 3             1         8         1         9         6         7         7
# 4             1         1         3         5         3         1         1
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995         7         7         6         3         2         9         1
# 99996         9         3         1         5         3         8         3
# 99997         8         5         5         5         4         8         5
# 99998         5         8         3         2         7         8         5
# 99999         9         4         5         3         5         4         5
#
#        Column_8  Column_9  Column_10  ...  Column_91  Column_92  Column_93  \
# 0             8         5          4  ...          1          7          7
# 1             9         3          7  ...          3          4          7
# 2             9         4          1  ...          9          6          3
# 3             3         2          9  ...          5          4          8
# 4             8         2          3  ...          8          1          6
# ...         ...       ...        ...  ...        ...        ...        ...
# 99995         4         2          8  ...          6          1          4
# 99996         4         9          1  ...          3          8          6
# 99997         2         9          2  ...          2          8          7
# 99998         4         6          7  ...          3          9          5
# 99999         9         9          1  ...          7          2          8
#
#        Column_94  Column_95  Column_96  Column_97  Column_98  Column_99  \
# 0              8          5          3          8          6          3
# 1              4          9          1          8          7          2
# 2              8          8          2          6          7          2
# 3              7          2          1          4          8          2
# 4              4          1          7          9          4          4
# ...          ...        ...        ...        ...        ...        ...
# 99995          9          5          4          1          7          9
# 99996          8          4          7          9          1          9
# 99997          2          5          9          5          1          4
# 99998          1          8          7          2          7          7
# 99999          7          4          2          4          2          3
#
#        Column_100
# 0               1
# 1               8
# 2               2
# 3               3
# 4               6
# ...           ...
# 99995           2
# 99996           9
# 99997           1
# 99998           4
# 99999           5
#
# [100000 rows x 100 columns]

# %%
df.groupby(df.columns.tolist(),as_index=False).size()
# Out:
# C:\Users\PREDATOR08\AppData\Local\Temp\ipykernel_17440\1185905868.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.groupby(df.columns.tolist(),as_index=False).size()
#        Column_1  Column_2  Column_3  Column_4  Column_5  Column_6  Column_7  \
# 0             1         1         1         1         1         9         4
# 1             1         1         1         1         1         9         5
# 2             1         1         1         1         2         4         4
# 3             1         1         1         1         2         9         6
# 4             1         1         1         1         3         1         1
# ...         ...       ...       ...       ...       ...       ...       ...
# 90979         9         9         9         9         7         6         6
# 90980         9         9         9         9         7         9         1
# 90981         9         9         9         9         8         2         8
# 90982         9         9         9         9         9         1         5
# 90983         9         9         9         9         9         4         1
#
#        Column_8  Column_9  Column_10  ...  Column_92  Column_93  Column_94  \
# 0             7         3          3  ...          7          3          2
# 1             2         3          6  ...          5          7          9
# 2             7         3          3  ...          5          8          2
# 3             4         7          9  ...          5          5          7
# 4             5         6          3  ...          6          5          9
# ...         ...       ...        ...  ...        ...        ...        ...
# 90979         2         2          8  ...          1          5          7
# 90980         1         7          9  ...          5          6          7
# 90981         7         4          5  ...          4          1          6
# 90982         5         1          7  ...          1          9          9
# 90983         2         3          3  ...          4          3          2
#
#        Column_95  Column_96  Column_97  Column_98  Column_99  Column_100  size
# 0              8          9          9          7          7           4     1
# 1              9          1          6          3          4           7     1
# 2              7          2          6          9          2           5     1
# 3              5          5          6          1          3           2     2
# 4              7          6          2          8          1           9     1
# ...          ...        ...        ...        ...        ...         ...   ...
# 90979          3          9          5          7          2           8     2
# 90980          4          8          2          7          9           9     2
# 90981          7          3          2          7          9           3     1
# 90982          9          7          8          1          1           8     1
# 90983          3          1          5          2          1           7     1
#
# [90984 rows x 101 columns]

# %%
df.to_csv('data.csv', index=False)
